# %% [markdown]
# This notebook works with anonymized data of sexual harassment charges filed to the [U.S. Equal Employment
# Opportunity Commission](https://www.eeoc.gov/) (EEOC) and aggregated data from the [Bureau of Labor Statistics](https://www.bls.gov). The code below does the following:
#
# * Combines separate spreadsheets supplied by the EEOC into one data frame and eliminates duplicates
# * Merges this data with data on gender, wages and total employment from the Bureau of Labor Statistics
# * Aggregates the data for each industry
# * Aggregates the data for each sector

# %% [markdown]
# ## Load and combine EEOC data

# %%
import pandas as pd

# %% [markdown]
# The data supplied by the EEOC came in three separate sheets, with a maximum of 65,000 rows each. We were instructed to combine them.

# %%
def parse_eeoc(path, sheet_name):
    df = pd.read_excel(
        path,
        sheet_name=sheet_name,
        dtype={
            "R_NAICS_CODE": str
        },
        parse_dates=[ "CHARGE_FILING_DATE" ]
    )
    print(len(df))
    df["R_NAICS_DESCRIPTION"] = df["R_NAICS_DESCRIPTION"].str.strip()
    return df

# %%
all_eeoc_data = pd.concat([ parse_eeoc("../data/SH Charge Receipts.xlsx", name )
    for name in [ "Sheet 1", "Sheet 2", "Sheet 3" ] ])

print(len(all_eeoc_data))
all_eeoc_data.head()
# Out:
# 64999
# 64999
# 40024
# 170022
#   CHARGE_FILING_DATE  CP_SEX                CP_NATIONAL_ORIGIN  \
# 0         1995-10-01  Female  Other National Origin - Obsolete
# 1         1995-10-02  Female  Other National Origin - Obsolete
# 2         1995-10-02  Female  Other National Origin - Obsolete
# 3         1995-10-02    Male  Other National Origin - Obsolete
# 4         1995-10-02  Female  Other National Origin - Obsolete
#
#                 CP_DOB HISPANIC_CP CP_RACE_STRING R_NAICS_CODE  \
# 0  1969-10-21 00:00:00         NaN              B       311612
# 1  2001-01-01 00:00:00         NaN              O       541990
# 2  1960-07-30 00:00:00         NaN              W       722110
# 3  1957-06-02 00:00:00         NaN              B       422990
# 4  1959-04-15 00:00:00         NaN              W       523999
#
#                                  R_NAICS_DESCRIPTION R_NUMBER_OF_EMPLOYEES  \
# 0                      Meat Processed from Carcasses   201 - 500 Employees
# 1  All Other Professional, Scientific, and Techni...    15 - 100 Employees
# 2                           Full-Service Restaurants    15 - 100 Employees
# 3   Other Miscellaneous Nondurable Goods Wholesalers    15 - 100 Employees
# 4      Miscellaneous Financial Investment Activities        501+ Employees
#
#              R_TYPE
# 0  Private Employer
# 1  Private Employer
# 2  Private Employer
# 3  Private Employer
# 4  Private Employer

# %% [markdown]
# There are a handful of duplicates; here, we remove them:

# %%
claims = all_eeoc_data.drop_duplicates().copy()
print(len(claims))
# Out:
# 170022

# %% [markdown]
# ## Aggregate claims by NAICS codes

# %%
grp = claims.fillna("No category")\
    .groupby([ "R_NAICS_CODE", "R_NAICS_DESCRIPTION" ])

claims_by_naics = pd.DataFrame({
    "claims_total": grp.size(),
    "claims_2016": grp["CHARGE_FILING_DATE"].apply(lambda x: (x.dt.year == 2016).sum())
}).reset_index()

claims_by_naics.head()
# Out:
#   R_NAICS_CODE                                R_NAICS_DESCRIPTION  \
# 0       111110                                    Soybean Farming
# 1       111150                                       Corn Farming
# 2       111199                            All Other Grain Farming
# 3       111219  Other Vegetable (except Potato) and Melon Farming
# 4       111310                                      Orange Groves
#
#    claims_2016  claims_total
# 0            0             1
# 1            0             3
# 2            0            15
# 3            1            20
# 4            0             3

# %%
claims_by_naics["claims_total"].sum()
# Out:
# 170022

# %%
claims_by_naics["claims_2016"].sum()
# Out:
# 5236

# %% [markdown]
# ## Merge BLS data
#
# Here, we read in data that we created in the previous notebook, `01-merge-bls-data.ipynb`.

# %%
ces_industry_metrics = pd.read_csv(
    "../output/ces_industry_metrics.csv",
    dtype={ "naics_code": str }
)

bls_sector_metrics = pd.read_csv(
    "../output/bls_sector_metrics.csv",
    dtype={ "naics_code": str, "naics_sector": str, "naics_sector_rollup": str }
)

# %% [markdown]
# Some NAICS titles appear under different NAICS codes, but these multiples all belong to the same NAICS sector:

# %%
grp = claims_by_naics[
    claims_by_naics["R_NAICS_DESCRIPTION"].isin(
        claims_by_naics["R_NAICS_DESCRIPTION"].value_counts().pipe(lambda x: x[x > 1]).index
    )
].groupby("R_NAICS_DESCRIPTION")
grp["R_NAICS_CODE"].apply(lambda x: x.str[:2].unique())
# Out:
# R_NAICS_DESCRIPTION
# All Other Information Services                                                   [51]
# Cable and Other Program Distribution                                             [51]
# Cafeterias, Grill Buffets, and Buffets                                           [72]
# Cellular and Other Wireless Telecommunications                                   [51]
# Commercial and Institutional Building Construction                               [23]
# Employment Placement Agencies                                                    [56]
# Food Product Machinery Manufacturing                                             [33]
# Full-Service Restaurants                                                         [72]
# Household Appliance Stores                                                       [44]
# Limited-Service Restaurants                                                      [72]
# No category                                                      [42, 44, 51, 56, na]
# Other Commercial and Service Industry Machinery Manufacturing                    [33]
# Other Electric Power Generation                                                  [22]
# Other Telecommunications                                                         [51]
# Painting and Wall Covering Contractors                                           [23]
# Plumbing, Heating, and Air-Conditioning Contractors                              [23]
# Radio Stations                                                                   [51]
# Satellite Telecommunications                                                     [51]
# Snack and Nonalcoholic Beverage Bars                                             [72]
# Telecommunications Resellers                                                     [51]
# Television Broadcasting                                                          [51]
# Wired Telecommunications Carriers                                                [51]
# Name: R_NAICS_CODE, dtype: object

# %%
grp = claims_by_naics.sort_values("R_NAICS_CODE").groupby("R_NAICS_DESCRIPTION")
claims_by_naics_desc = pd.DataFrame({
    "claims_2016": grp["claims_2016"].sum(),
    "claims_total": grp["claims_total"].sum(),
    "R_NAICS_CODE": grp["R_NAICS_CODE"].apply(",".join),
    "n_codes": grp.size()
}).drop("No category")\
    .reset_index()
claims_by_naics_desc.head()
# Out:
#                                  R_NAICS_DESCRIPTION R_NAICS_CODE  \
# 0                             Adhesive Manufacturing       325520
# 1  Administration of Air and Water Resource and S...       924110
# 2            Administration of Conservation Programs       924120
# 3               Administration of Education Programs       923110
# 4        Administration of General Economic Programs       926110
#
#    claims_2016  claims_total  n_codes
# 0            0             2        1
# 1            2            97        1
# 2            2             4        1
# 3            1            79        1
# 4            0            45        1

# %%
claims_by_desc_with_meta = claims_by_naics_desc.pipe(pd.merge,
    ces_industry_metrics,
    left_on="R_NAICS_CODE",
    right_on="naics_code",
    how="left"
)\
.assign(naics_sector=lambda x: x["R_NAICS_CODE"].str[:2])\
.pipe(pd.merge,
    bls_sector_metrics,
    how="left",
    on="naics_sector",
    suffixes=[ "", "_meta" ]
)

claims_by_desc_with_meta.head().T
# Out:
#                                                0  \
# R_NAICS_DESCRIPTION       Adhesive Manufacturing
# R_NAICS_CODE                              325520
# claims_2016                                    0
# claims_total                                   2
# n_codes                                        1
# industry_code                                NaN
# avg_hrly_earnings                            NaN
# total_employment                             NaN
# women_employment                             NaN
# naics_supersector                            NaN
# naics_code                                   NaN
# naics_sector_rollup                          NaN
# women_percentage                             NaN
# source                                       NaN
# naics_sector                                  32
# naics_sector_rollup_meta                      31
# naics_supersector_meta                        30
# naics_sector_name                  Manufacturing
# avg_hrly_earnings_meta                     24.39
# total_employment_meta                    12337.5
# women_percentage_meta                   0.274534
# source_meta                  oes,ces_supersector
#
#                                                                           1  \
# R_NAICS_DESCRIPTION       Administration of Air and Water Resource and S...
# R_NAICS_CODE                                                         924110
# claims_2016                                                               2
# claims_total                                                             97
# n_codes                                                                   1
# industry_code                                                           NaN
# avg_hrly_earnings                                                       NaN
# total_employment                                                        NaN
# women_employment                                                        NaN
# naics_supersector                                                       NaN
# naics_code                                                              NaN
# naics_sector_rollup                                                     NaN
# women_percentage                                                        NaN
# source                                                                  NaN
# naics_sector                                                             92
# naics_sector_rollup_meta                                                 92
# naics_supersector_meta                                                   90
# naics_sector_name                                     Public Administration
# avg_hrly_earnings_meta                                                28.26
# total_employment_meta                                                  5101
# women_percentage_meta                                              0.537346
# source_meta                                                         oes,ces
#
#                                                                 2  \
# R_NAICS_DESCRIPTION       Administration of Conservation Programs
# R_NAICS_CODE                                               924120
# claims_2016                                                     2
# claims_total                                                    4
# n_codes                                                         1
# industry_code                                                 NaN
# avg_hrly_earnings                                             NaN
# total_employment                                              NaN
# women_employment                                              NaN
# naics_supersector                                             NaN
# naics_code                                                    NaN
# naics_sector_rollup                                           NaN
# women_percentage                                              NaN
# source                                                        NaN
# naics_sector                                                   92
# naics_sector_rollup_meta                                       92
# naics_supersector_meta                                         90
# naics_sector_name                           Public Administration
# avg_hrly_earnings_meta                                      28.26
# total_employment_meta                                        5101
# women_percentage_meta                                    0.537346
# source_meta                                               oes,ces
#
#                                                              3  \
# R_NAICS_DESCRIPTION       Administration of Education Programs
# R_NAICS_CODE                                            923110
# claims_2016                                                  1
# claims_total                                                79
# n_codes                                                      1
# industry_code                                              NaN
# avg_hrly_earnings                                          NaN
# total_employment                                           NaN
# women_employment                                           NaN
# naics_supersector                                          NaN
# naics_code                                                 NaN
# naics_sector_rollup                                        NaN
# women_percentage                                           NaN
# source                                                     NaN
# naics_sector                                                92
# naics_sector_rollup_meta                                    92
# naics_supersector_meta                                      90
# naics_sector_name                        Public Administration
# avg_hrly_earnings_meta                                   28.26
# total_employment_meta                                     5101
# women_percentage_meta                                 0.537346
# source_meta                                            oes,ces
#
#                                                                     4
# R_NAICS_DESCRIPTION       Administration of General Economic Programs
# R_NAICS_CODE                                                   926110
# claims_2016                                                         0
# claims_total                                                       45
# n_codes                                                             1
# industry_code                                                     NaN
# avg_hrly_earnings                                                 NaN
# total_employment                                                  NaN
# women_employment                                                  NaN
# naics_supersector                                                 NaN
# naics_code                                                        NaN
# naics_sector_rollup                                               NaN
# women_percentage                                                  NaN
# source                                                            NaN
# naics_sector                                                       92
# naics_sector_rollup_meta                                           92
# naics_supersector_meta                                             90
# naics_sector_name                               Public Administration
# avg_hrly_earnings_meta                                          28.26
# total_employment_meta                                            5101
# women_percentage_meta                                        0.537346
# source_meta                                                   oes,ces

# %%
assert claims_by_desc_with_meta["women_percentage_meta"].isnull().sum() == 0

# %%
for col in [ "women_percentage", "avg_hrly_earnings", "total_employment" ]:
    claims_by_desc_with_meta[col + "_best"] = claims_by_desc_with_meta[col]\
        .fillna(claims_by_desc_with_meta[col + "_meta"])

# %%
claims_by_desc_with_meta["does_not_have_detailed"] = claims_by_desc_with_meta["women_percentage"].isnull()

# %% [markdown]
# ## Merge graphics info

# %%
graphics_info = pd.read_csv(
    "../data/graphics_info.csv",
    dtype={
        "naics_code":str, 
        "focus":str,
        "index_num":str,
        "industry_code":str
    }
)

graphics_info.head()
# Out:
#                                         industry naics_code  \
# 0                Accommodation and Food Services         72
# 1                                   Retail Trade         44
# 2  Other Services (except Public Administration)         81
# 3                                Wholesale Trade         42
# 4                                  Manufacturing         31
#
#                          grouping                industry_class  \
# 0  Service and sales-related jobs  accommodationandfoodservices
# 1  Service and sales-related jobs                   retailtrade
# 2  Service and sales-related jobs                 otherservices
# 3  Service and sales-related jobs                wholesaletrade
# 4                    Manual Labor                 manufacturing
#
#                grouping_class    color focus index_num  \
# 0  serviceandsalesrelatedjobs  #af2469     1         1
# 1  serviceandsalesrelatedjobs  #f43192     1         2
# 2  serviceandsalesrelatedjobs  #efb4d1     1         3
# 3  serviceandsalesrelatedjobs  #efdce7     1         4
# 4                 manuallabor  #096c5f     2         1
#
#                                            info_text
# 0  By far, the most claims were filed by service-...
# 1  By far, the most claims were filed by service-...
# 2  By far, the most claims were filed by service-...
# 3  By far, the most claims were filed by service-...
# 4  Manual labor jobs like construction, warehousi...

# %%
for_graphic = pd.merge(
    claims_by_desc_with_meta,
    graphics_info.drop(["info_text", "naics_code"], axis=1),
    left_on="naics_sector_name",
    right_on="industry"
)

# %%
for_graphic.to_csv("../output/d3_claims_by_industry.csv", index=False)

# %% [markdown]
# ## Aggregate claims by NAICS sector

# %%
claims["naics_sector"] = claims["R_NAICS_CODE"].str[:2]

# %%
grp = claims.fillna("No category")\
    .groupby([ "naics_sector" ])

claims_by_naics_sector = pd.DataFrame({
    "claims_total": grp.size(),
    "claims_2016": grp["CHARGE_FILING_DATE"].apply(lambda x: (x.dt.year == 2016).sum())
}).reset_index()

claims_by_naics_sector.head()
# Out:
#   naics_sector  claims_2016  claims_total
# 0           11           23           950
# 1           21            8           700
# 2           22            9           693
# 3           23           46          3070
# 4           31           51          3410

# %%
claims_by_naics_sector["claims_total"].sum()
# Out:
# 170022

# %%
claims_by_naics_sector["claims_2016"].sum()
# Out:
# 5236

# %%
sectors = pd.read_csv("../data/naics_sectors.csv", dtype=str)

# %%
pd.merge(
    claims_by_naics_sector,
    sectors,
    on="naics_sector",
    how="left"
).fillna("n/a")
# Out:
#    naics_sector  claims_2016  claims_total naics_sector_rollup  \
# 0            11           23           950                  11
# 1            21            8           700                  21
# 2            22            9           693                  22
# 3            23           46          3070                  23
# 4            31           51          3410                  31
# 5            32           48          3004                  31
# 6            33          162          7639                  31
# 7            42           44          2287                  42
# 8            44          140          8358                  44
# 9            45           77          5761                  44
# 10           48           71          4048                  48
# 11           49           27           683                  48
# 12           51           41          3949                  51
# 13           52           66          4707                  52
# 14           53           24          2050                  53
# 15           54           91          6830                  54
# 16           55           26           309                  55
# 17           56          168          6288                  56
# 18           61           76          3977                  61
# 19           62          221         10090                  62
# 20           71           39          1538                  71
# 21           72          237         14208                  72
# 22           81           41          3403                  81
# 23           92          125          7627                  92
# 24           na         3375         64443                 n/a
#
#    naics_supersector                                  naics_sector_name
# 0                n/a         Agriculture, Forestry, Fishing and Hunting
# 1                 10      Mining, Quarrying, and Oil and Gas Extraction
# 2                 40                                          Utilities
# 3                 20                                       Construction
# 4                 30                                      Manufacturing
# 5                 30                                      Manufacturing
# 6                 30                                      Manufacturing
# 7                 40                                    Wholesale Trade
# 8                 40                                       Retail Trade
# 9                 40                                       Retail Trade
# 10                40                     Transportation and Warehousing
# 11                40                     Transportation and Warehousing
# 12                50                                        Information
# 13                55                              Finance and Insurance
# 14                55                 Real Estate and Rental and Leasing
# 15                60   Professional, Scientific, and Technical Services
# 16                60            Management of Companies and Enterprises
# 17                60  Administrative and Support and Waste Managemen...
# 18                65                               Educational Services
# 19                65                  Health Care and Social Assistance
# 20                70                Arts, Entertainment, and Recreation
# 21                70                    Accommodation and Food Services
# 22                80      Other Services (except Public Administration)
# 23                90                              Public Administration
# 24               n/a                                                n/a

# %%
grp = pd.merge(
    claims_by_naics_sector,
    sectors,
    on="naics_sector",
    how="left"
).fillna("No category").groupby("naics_sector_rollup")

sector_for_graphics = pd.DataFrame({
    "claims_2016": grp["claims_2016"].sum().astype(int),
    "claims_total": grp["claims_total"].sum().astype(int),
    "naics_sector_name": grp["naics_sector_name"].first()
}).reset_index().pipe(pd.merge,
    graphics_info,
    how="right",
    left_on="naics_sector_name",
    right_on="industry"
).drop("naics_sector_name", axis=1)

sector_for_graphics.head()
# Out:
#   naics_sector_rollup  claims_2016  claims_total  \
# 0                  11           23           950
# 1                  21            8           700
# 2                  22            9           693
# 3                  23           46          3070
# 4                  31          261         14053
#
#                                         industry naics_code      grouping  \
# 0     Agriculture, Forestry, Fishing and Hunting         11  Manual Labor
# 1  Mining, Quarrying, and Oil and Gas Extraction         21  Manual Labor
# 2                                      Utilities         22  Manual Labor
# 3                                   Construction         23  Manual Labor
# 4                                  Manufacturing         31  Manual Labor
#
#                           industry_class grouping_class    color focus  \
# 0   agricultureforestryfishingandhunting    manuallabor  #a4ffe6     2
# 1  miningquarryingandoilandgasextraction    manuallabor  #bfec89     2
# 2                              utilities    manuallabor  #e7f9d2     2
# 3                           construction    manuallabor  #0dccb0     2
# 4                          manufacturing    manuallabor  #096c5f     2
#
#   index_num                                          info_text
# 0         4  Manual labor jobs like construction, warehousi...
# 1         5  Manual labor jobs like construction, warehousi...
# 2         6  Manual labor jobs like construction, warehousi...
# 3         3  Manual labor jobs like construction, warehousi...
# 4         1  Manual labor jobs like construction, warehousi...

# %%
len(sector_for_graphics)
# Out:
# 21

# %%
sector_for_graphics.to_csv("../output/d3_claims_by_sector.csv")

# %% [markdown]
# ### Additional aggregation for article

# %%
claims.fillna("[missing]")["CP_SEX"].value_counts().to_frame("claims")\
    .assign(prop=lambda x: x["claims"] / len(claims))
# Out:
#                                  claims      prop
# Female                           141380  0.831539
# Male                              25503  0.149998
# CP Sex Not Available/Applicable    3087  0.018156
# [missing]                            52  0.000306

# %% [markdown]
# ---
#
# ---
#
# ---
